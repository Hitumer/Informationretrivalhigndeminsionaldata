# %%
import numpy as np
import imageio
import os
train_labels = list()
directory = '/yaleBfaces/subset0'
N = len(os.listdir(directory))
T = np.zeros((N,2500))
for i,file in enumerate(os.listdir(directory)):
    img = imageio.imread(os.path.join(directory,file))
    T[i,:] = np.float64(img.ravel())
    train_labels.append(''.join(char for char in file.split('_')[0] if char.isdigit()))
train_labels = np.array([int(label) for label in train_labels])
T = np.transpose(T)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py in convert(self, mode, matrix, dither, palette, colors)
#    1045         try:
# -> 1046             im = self.im.convert(mode, dither)
#    1047         except ValueError:
#
# ValueError: conversion from L to png not supported
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/xb/54n0yjj110577z7wbb09w97c0000gn/T/ipykernel_18087/1846547285.py in <module>
#       7 T = np.zeros((N,2500))
#       8 for i,file in enumerate(os.listdir(directory)):
# ----> 9     img = imageio.imread(os.path.join(directory,file),pilmode="png")
#      10     T[i,:] = np.float64(img.ravel())
#      11     train_labels.append(''.join(char for char in file.split('_')[0] if char.isdigit()))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/imageio/core/functions.py in imread(uri, format, **kwargs)
#     265     reader = read(uri, format, "i", **kwargs)
#     266     with reader:
# --> 267         return reader.get_data(0)
#     268
#     269
#
# ~/opt/anaconda3/lib/python3.9/site-packages/imageio/core/format.py in get_data(self, index, **kwargs)
#     344             self._BaseReaderWriter_last_index = index
#     345             try:
# --> 346                 im, meta = self._get_data(index, **kwargs)
#     347             except StopIteration:
#     348                 raise IndexError(index)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/imageio/plugins/pillow.py in _get_data(self, index)
#     299
#     300         def _get_data(self, index):
# --> 301             im, info = PillowFormat.Reader._get_data(self, index)
#     302             if not self.request.kwargs.get("ignoregamma", True):
#     303                 # The gamma value in the file represents the gamma factor for the
#
# ~/opt/anaconda3/lib/python3.9/site-packages/imageio/plugins/pillow.py in _get_data(self, index)
#     178                 self._im.palette.rawmode_saved = self._im.palette.rawmode
#     179             self._im.getdata()[0]
# --> 180             im = pil_get_frame(self._im, **self._kwargs)
#     181             return im, self._im.info
#     182
#
# ~/opt/anaconda3/lib/python3.9/site-packages/imageio/plugins/pillow.py in pil_get_frame(im, is_gray, as_gray, mode, dtype)
#     712         # Mode is explicitly given ...
#     713         if mode != im.mode:
# --> 714             frame = im.convert(mode)
#     715     elif as_gray:
#     716         pass  # don't do any auto-conversions (but do the explit one above)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py in convert(self, mode, matrix, dither, palette, colors)
#    1049                 # normalize source image and try again
#    1050                 im = self.im.convert(getmodebase(self.mode))
# -> 1051                 im = im.convert(mode, dither)
#    1052             except KeyError as e:
#    1053                 raise ValueError("illegal conversion") from e
#
# ValueError: conversion from L to png not supported

# %%
u,s,vh = np.linalg.svd(T)
U = u[:,0:20]

# %%
import matplotlib.pyplot as plt
for j in range(3):
    plt.subplot(1,3,j+1)
    plt.imshow(U[:,j].reshape(50,50))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/xb/54n0yjj110577z7wbb09w97c0000gn/T/ipykernel_18087/4019570850.py in <module>
#       2 for j in range(3):
#       3     plt.subplot(1,3,j+1)
# ----> 4     plt.imshow(U[:,j].reshape(50,50))
#       5     plt.show()
#
# ValueError: cannot reshape array of size 71 into shape (50,50)

# %%
path = 'yaleBfaces/subset0/'
T = np.zeros((2500, 0))
train_labels = list()
for i, file in enumerate(os.listdir(path)):
    img = imageio.imread(os.path.join(path, file))
    img = img.reshape(-1, 1)
    T = np.hstack((T, img))
    train_labels.append(''.join(char for char in file.split('_')[0] if char.isdigit()))
    
train_labels = np.array([int(label) for label in train_labels])
# indices = np.arange(T.shape[1])
# np.random.shuffle(indices)
# T = T.T[indices].T
# train_labels = train_labels[indices]

idx = np.random.randint(10)
def visualize(T, train_labels):
    plt.figure(figsize=(20, 20))
    for i in range(7):
        plt.subplot(4,3,i+1)
        plt.imshow(T[:,i+7*idx].reshape(50, 50), cmap='gray')
        plt.title(str(train_labels[i+7*idx]))
    plt.show()
    
visualize(T, train_labels)
